# %% [markdown]
# ## 1. Load the dataset into a DataFrame.

# %%
import numpy as np
import pandas as pd
data = pd.read_csv(
    "D:/Machine-Learning/Data/SCMS_Delivery_History_Dataset.csv")
data
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %% [markdown]
# ## 2. Display first 10 rows.

# %%
data.head(10)
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# 5  23   112-NG-T01  Pre-PQ Process   SCMS-87   ASN-57        Nigeria
# 6  44   110-ZM-T01  Pre-PQ Process  SCMS-139  ASN-130         Zambia
# 7  45   109-TZ-T01  Pre-PQ Process  SCMS-140   ASN-94       Tanzania
# 8  46   112-NG-T01  Pre-PQ Process  SCMS-156   ASN-93        Nigeria
# 9  47   110-ZM-T01  Pre-PQ Process  SCMS-165  ASN-199         Zambia
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# ...

# %% [markdown]
# ## 3. Show all column names.

# %%
data.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %% [markdown]
# ## 4. Check data types of all columns.

# %%
data.dtypes
# Out:
# ID                                int64
# Project Code                     object
# PQ #                             object
# PO / SO #                        object
# ASN/DN #                         object
# Country                          object
# Managed By                       object
# Fulfill Via                      object
# Vendor INCO Term                 object
# Shipment Mode                    object
# PQ First Sent to Client Date     object
# PO Sent to Vendor Date           object
# Scheduled Delivery Date          object
# Delivered to Client Date         object
# Delivery Recorded Date           object
# Product Group                    object
# Sub Classification               object
# Vendor                           object
# Item Description                 object
# Molecule/Test Type               object
# Brand                            object
# Dosage                           object
# Dosage Form                      object
# ...

# %% [markdown]
# ## 5. Find total number of rows and columns.

# %%
data.shape
# Out:
# (8158, 33)

# %% [markdown]
# ## 6. Count missing values per column.

# %%
data.count().isnull()
# Out:
# ID                              False
# Project Code                    False
# PQ #                            False
# PO / SO #                       False
# ASN/DN #                        False
# Country                         False
# Managed By                      False
# Fulfill Via                     False
# Vendor INCO Term                False
# Shipment Mode                   False
# PQ First Sent to Client Date    False
# PO Sent to Vendor Date          False
# Scheduled Delivery Date         False
# Delivered to Client Date        False
# Delivery Recorded Date          False
# Product Group                   False
# Sub Classification              False
# Vendor                          False
# Item Description                False
# Molecule/Test Type              False
# Brand                           False
# Dosage                          False
# Dosage Form                     False
# Unit of Measure (Per Pack)      False
# Line Item Quantity              False
# ...

# %% [markdown]
# ## 7. Drop all rows where any value is missing.

# %%
data.dropna(inplace=True)

# %% [markdown]
# ## 8. Select only numeric columns.

# %%
numeric = data.select_dtypes(include='number')
numeric
# Out:
#           ID  Unit of Measure (Per Pack)  Line Item Quantity  Line Item Value  \
# 21       108                          60                5513        140581.50
# 22       115                         240                1000          1920.00
# 23       116                         120                 500         41095.00
# 29       161                          60               64000         99200.00
# 32       269                          30                1000         17000.00
# ...      ...                         ...                 ...              ...
# 10319  86818                          60              166571        599655.60
# 10320  86819                          60               21072        137389.44
# 10321  86821                          30              514526       5140114.74
# 10322  86822                          60               17465        113871.80
# 10323  86823                          60               36639         72911.61
#
# ...

# %% [markdown]
# ## 9. Find unique values in `Country`.

# %%
data['Country'].unique()
# Out:
# array(["Côte d'Ivoire", 'Vietnam', 'Ethiopia', 'South Africa', 'Tanzania',
#        'Nigeria', 'Haiti', 'Rwanda', 'Uganda', 'Namibia', 'Guyana',
#        'Zambia', 'Mozambique', 'Zimbabwe', 'Swaziland', 'Ghana',
#        'Lebanon', 'Kenya', 'Dominican Republic', 'Malawi', 'Congo, DRC',
#        'Benin', 'Cameroon', 'Guatemala', 'Togo', 'Angola', 'Afghanistan',
#        'Burkina Faso', 'South Sudan', 'Senegal', 'Botswana', 'Burundi',
#        'Libya', 'Belize'], dtype=object)

# %% [markdown]
# ## 10. Count number of deliveries per `Country`.

# %%
data["Country"].value_counts()
# Out:
# Country
# South Africa          1364
# Nigeria                952
# Côte d'Ivoire          827
# Uganda                 724
# Vietnam                661
# Haiti                  549
# Mozambique             506
# Zimbabwe               471
# Zambia                 470
# Tanzania               374
# Rwanda                 336
# Congo, DRC             245
# Guyana                 162
# Ethiopia               127
# Burundi                 72
# Ghana                   58
# Cameroon                54
# South Sudan             52
# Dominican Republic      37
# Namibia                 30
# Swaziland               21
# Guatemala               15
# Benin                   10
# Libya                    8
# Lebanon                  8
# Kenya                    4
# Malawi                   4
# Afghanistan              3
# Angola                   3
# Botswana                 3
# Togo                     3
# Burkina Faso             2
# Senegal                  2
# Belize                   1
# ...

# %% [markdown]
# ## 11. Filter deliveries where `Shipment Mode` is 'Air'.

# %%
Air = data[data['Shipment Mode']=='Air']
Air.head(10)
# Out:
#      ID Project Code            PQ #   PO / SO #  ASN/DN #        Country  \
# 21  108   104-CI-T01  Pre-PQ Process    SCMS-698   ASN-727  Côte d'Ivoire
# 22  115   108-VN-T01  Pre-PQ Process    SCMS-753   ASN-781        Vietnam
# 23  116   108-VN-T01  Pre-PQ Process    SCMS-759   ASN-632        Vietnam
# 29  161   117-ET-T01  Pre-PQ Process  SCMS-11070   ASN-916       Ethiopia
# 32  269   108-VN-T01  Pre-PQ Process  SCMS-14190  ASN-1192        Vietnam
# 33  270   108-VN-T01  Pre-PQ Process  SCMS-14200  ASN-1171        Vietnam
# 46  420   108-VN-T01  Pre-PQ Process  SCMS-19490  ASN-1753        Vietnam
# 49  438   108-VN-T01  Pre-PQ Process  SCMS-20310  ASN-1923        Vietnam
# 54  530   108-VN-T01  Pre-PQ Process  SCMS-23450  ASN-2336        Vietnam
# 58  535   109-TZ-T01  Pre-PQ Process  SCMS-23610  ASN-2167       Tanzania
#
#    Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 21   PMO - US  Direct Drop              CIP           Air  ...
# ...

# %% [markdown]
# ## 12. Find total shipment cost.

# %%
data['Freight Cost (USD)'].head(20)
# Out:
# 21    Freight Included in Commodity Cost
# 22                               4193.49
# 23                               1767.38
# 29                              12237.61
# 32                               2282.57
# 33                               2149.05
# 46                               4051.34
# 47    Freight Included in Commodity Cost
# 48    Freight Included in Commodity Cost
# 49                               2211.05
# 54                              13507.92
# 55    Freight Included in Commodity Cost
# 56    Freight Included in Commodity Cost
# 57    Freight Included in Commodity Cost
# 58                                 645.1
# 61    Freight Included in Commodity Cost
# 62                              18614.72
# 63                               1755.87
# 64                              10179.16
# 65    Freight Included in Commodity Cost
# Name: Freight Cost (USD), dtype: object

# %% [markdown]
# ## 13. Find average shipment cost.

# %% [markdown]
# ## 14. Find maximum and minimum shipment cost.

# %% [markdown]
# ## 15. Sort dataset by shipment cost descending.

# %% [markdown]
# ## 16. Group by `Country` and calculate average shipment cost.

# %% [markdown]
# ## 17. Find total cost per `Shipment Mode`.

# %% [markdown]
# ## 18. Count deliveries per `Vendor`.

# %% [markdown]
# ## 19. Find top 5 countries with highest number of deliveries.

# %% [markdown]
# ## 20. Find country with highest average cost.

# %% [markdown]
# ## 21. Group by `Product Category` and calculate total shipments.

# %% [markdown]
# ## 22. Find total cost per `Year`.

# %% [markdown]
# ## 23. Calculate percentage of deliveries per shipment mode.

# %% [markdown]
# ## 24. Find duplicate rows.

# %% [markdown]
# ## 25. Remove duplicate rows.

# %% [markdown]
# ## 26. Create a new column `Cost_per_Unit` = Total Cost / Units.

# %% [markdown]
# ## 27. Filter deliveries where cost per unit > overall average.

# %% [markdown]
# ## 28. Find median shipment cost per country.

# %% [markdown]
# ## 29. Calculate standard deviation of shipment cost per shipment mode.

# %% [markdown]
# ## 30. Find correlation between numeric columns.

# %% [markdown]
# ## 31. Create a pivot table: average cost per country and shipment mode.

# %% [markdown]
# ## 32. Find top 10 most expensive deliveries.

# %% [markdown]
# ## 33. Extract month from delivery date.

# %% [markdown]
# ## 34. Count deliveries per month.

# %% [markdown]
# ## 35. Find month with highest total cost.

# %% [markdown]
# ## 36. Find country with highest growth in shipment cost year-over-year.

# %% [markdown]
# ## 37. Calculate cumulative shipment cost over time.

# %% [markdown]
# ## 38. Find top vendor per country by shipment count.

# %% [markdown]
# ## 39. Find vendor with highest total revenue.

# %% [markdown]
# ## 40. Calculate delivery delay (Delivery Date – Order Date).

# %% [markdown]
# ## 41. Find average delay per shipment mode.

# %% [markdown]
# ## 42. Detect outliers in shipment cost using IQR.

# %% [markdown]
# ## 43. Rank countries by total shipment cost.

# %% [markdown]
# ## 44. Create cost category column (Low / Medium / High).

# %% [markdown]
# ## 45. Calculate rolling 3-month average shipment cost.

# %% [markdown]
# ## 46. Find shipments contributing to top 20% revenue (Pareto principle).

# %% [markdown]
# ## 47. Find most profitable product category per country.

# %% [markdown]
# ## 48. Create a summary DataFrame with total shipments, total cost, average cost, and most used shipment mode.

# %% [markdown]
# ## 49. Build a multi-index groupby: Country → Vendor → Total Cost.

# %% [markdown]
# ## 50. Create a final report sorted by Country, Total Revenue, Average Cost, Shipment Count.
